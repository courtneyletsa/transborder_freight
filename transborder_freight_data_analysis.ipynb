# %% [markdown]
# # TRANSBODER FREIGHT DATA ANALYSIS

# %% [markdown]
# The objective of this project is to analyze the transportation data provided by the Bureau of Transportation Statistics (BTS) to uncover insights related to the efficiency, safety, and environmental impacts of freight transportation across various modes (road, rail, air, and water). Using this data, the goal is to identify inefficiencies, recognize patterns, and propose actionable solutions to improve the overall performance and sustainability of transportation systems

# %% [markdown]
# IMPORT LIBRARIES

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# LOADING THE DATASET

# %%
base_dir = 'data_1'

# %%
# yearly_data = {}

# %%
year = 2020 # the single year you have

# Build the path for that year
year_path = os.path.join(base_dir, str(year))

# Collect every CSV in the month sub‑folders: data/2020/01/*.csv, 2020/02/*.csv, ...
all_files = glob.glob(os.path.join(year_path, '*/*.csv'))

if not all_files:
    raise FileNotFoundError(f'No CSV files found under {year_path}')

# Read and concatenate all CSVs for 2020
df_2020 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# Optional: store in a dict in case you add more years later
yearly_data = {year: df_2020}

# Quick check
df_2020.head()
# Out:
# <ipython-input-4-4f296898a795>:13: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_2020 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
# <ipython-input-4-4f296898a795>:13: DtypeWarning: Columns (4,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_2020 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
#    TRDTYPE USASTATE  DEPE  DISAGMOT MEXSTATE CANPROV  COUNTRY    VALUE  \
# 0        1       AK  0115         5      NaN      XB     1220     4660
# 1        1       AK  0901         5      NaN      XO     1220    14360
# 2        1       AK  20XX         1       XX     NaN     2010  4293733
# 3        1       AK  20XX         3      NaN      XA     1220    28283
# 4        1       AK  20XX         3      NaN      XA     1220    29848
#
#      SHIPWT  FREIGHT_CHARGES   DF CONTCODE  MONTH  YEAR  COMMODITY2
# 0         0               67  2.0        X      4  2020         NaN
# 1         0              282  1.0        X      4  2020         NaN
# 2  24971000                0  1.0        0      4  2020         NaN
# 3       443              563  1.0        X      4  2020         NaN
# 4        69              538  2.0        X      4  2020         NaN

# %%
year = 2021 # the single year you have

# Build the path for that year
year_path = os.path.join(base_dir, str(year))

# Collect every CSV in the month sub‑folders: data/2020/01/*.csv, 2020/02/*.csv, ...
all_files = glob.glob(os.path.join(year_path, '*/*.csv'))

if not all_files:
    raise FileNotFoundError(f'No CSV files found under {year_path}')

# Read and concatenate all CSVs for 2020
df_2021 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# Optional: store in a dict in case you add more years later
yearly_data = {year: df_2021}

# Quick check
df_2021.head()
# Out:
# <ipython-input-5-fde0c1a64dd1>:13: DtypeWarning: Columns (4,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_2021 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
# <ipython-input-5-fde0c1a64dd1>:13: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_2021 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
# <ipython-input-5-fde0c1a64dd1>:13: DtypeWarning: Columns (4,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_2021 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
#    TRDTYPE USASTATE  DEPE  DISAGMOT MEXSTATE CANPROV  COUNTRY  VALUE  SHIPWT  \
# 0        1       AK  07XX         3      NaN      XO     1220  13504      47
# 1        1       AK  18XX         1       XX     NaN     2010   6668     425
# 2        1       AK  20XX         3      NaN      XA     1220   5108     584
# 3        1       AK  20XX         3      NaN      XC     1220  24397     800
# 4        1       AK  20XX         3      NaN      XC     1220  18429     101
#
#    FREIGHT_CHARGES   DF CONTCODE  MONTH  YEAR  COMMODITY2
# 0              401  1.0        X    4.0  2021         NaN
# 1                0  1.0        1    4.0  2021         NaN
# 2               80  1.0        X    4.0  2021         NaN
# 3             1002  1.0        X    4.0  2021         NaN
# 4               80  2.0        X    4.0  2021         NaN

# %%
year = 2023 # the single year you have

# Build the path for that year
year_path = os.path.join(base_dir, str(year))

# Collect every CSV in the month sub‑folders: data/2020/01/*.csv, 2020/02/*.csv, ...
all_files = glob.glob(os.path.join(year_path, '*/*.csv'))

if not all_files:
    raise FileNotFoundError(f'No CSV files found under {year_path}')

# Read and concatenate all CSVs for 2020
df_2023 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# Optional: store in a dict in case you add more years later
yearly_data = {year: df_2023}

# Quick check
df_2023.head()
# Out:
# <ipython-input-6-b273ffaa827d>:13: DtypeWarning: Columns (4,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_2023 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
# <ipython-input-6-b273ffaa827d>:13: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_2023 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
#    TRDTYPE USASTATE  DEPE  DISAGMOT MEXSTATE CANPROV  COUNTRY   VALUE  SHIPWT  \
# 0        1       AK  0708         5      NaN      XQ     1220   21046       0
# 1        1       AK  07XX         3      NaN      XO     1220  185454     310
# 2        1       AK  09XX         3      NaN      XQ     1220   21660      51
# 3        1       AK  2006         3      NaN      XQ     1220    5053       5
# 4        1       AK  20XX         3      NaN      XA     1220   51328     675
#
#    FREIGHT_CHARGES   DF CONTCODE  MONTH  YEAR  COMMODITY2
# 0              412  2.0        X      4  2023         NaN
# 1             3337  1.0        X      4  2023         NaN
# 2              226  1.0        X      4  2023         NaN
# 3               99  2.0        X      4  2023         NaN
# 4             1271  1.0        X      4  2023         NaN

# %%
year = 2024 # the single year you have

# Build the path for that year
year_path = os.path.join(base_dir, str(year))

# Collect every CSV in the month sub‑folders: data/2020/01/*.csv, 2020/02/*.csv, ...
all_files = glob.glob(os.path.join(year_path, '*/*.csv'))

if not all_files:
    raise FileNotFoundError(f'No CSV files found under {year_path}')

# Read and concatenate all CSVs for 2020
df_2024 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# Optional: store in a dict in case you add more years later
yearly_data = {year: df_2024}

# Quick check
df_2024.head()
# Out:
# <ipython-input-7-1412c68adeee>:13: DtypeWarning: Columns (4,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_2024 = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
#    TRDTYPE USASTATE  DEPE  DISAGMOT MEXSTATE CANPROV  COUNTRY   VALUE  SHIPWT  \
# 0        1       AK  0712         5      NaN      XQ     1220   14609       0
# 1        1       AK  0901         5      NaN      XY     1220   26482       0
# 2        1       AK  19XX         1       XX     NaN     2010   72786   40210
# 3        1       AK  20XX         3      NaN      XA     1220  111914     775
# 4        1       AK  20XX         3      NaN      XA     1220   24831      63
#
#    FREIGHT_CHARGES   DF CONTCODE  MONTH  YEAR  COMMODITY2
# 0              286  1.0        X      4  2024         NaN
# 1               26  1.0        X      4  2024         NaN
# 2                0  1.0        0      4  2024         NaN
# 3              980  1.0        X      4  2024         NaN
# 4              178  2.0        X      4  2024         NaN

# %% [markdown]
# COMBINE YEARLY DATASETS

# %%
df_2020_2024 = pd.concat([df_2020, df_2021, df_2023, df_2024], ignore_index=True)
df_2020_2024.head()
# Out:
#    TRDTYPE USASTATE  DEPE  DISAGMOT MEXSTATE CANPROV  COUNTRY    VALUE  \
# 0        1       AK  0115         5      NaN      XB     1220     4660
# 1        1       AK  0901         5      NaN      XO     1220    14360
# 2        1       AK  20XX         1       XX     NaN     2010  4293733
# 3        1       AK  20XX         3      NaN      XA     1220    28283
# 4        1       AK  20XX         3      NaN      XA     1220    29848
#
#      SHIPWT  FREIGHT_CHARGES   DF CONTCODE  MONTH  YEAR  COMMODITY2
# 0         0               67  2.0        X    4.0  2020         NaN
# 1         0              282  1.0        X    4.0  2020         NaN
# 2  24971000                0  1.0        0    4.0  2020         NaN
# 3       443              563  1.0        X    4.0  2020         NaN
# 4        69              538  2.0        X    4.0  2020         NaN

# %% [markdown]
# INSPECTING THE DATA

# %%
df_2020_2024.shape
# Out:
# (24115277, 15)

# %%
df_2020_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24115277 entries, 0 to 24115276
# Data columns (total 15 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   TRDTYPE          int64
#  1   USASTATE         object
#  2   DEPE             object
#  3   DISAGMOT         int64
#  4   MEXSTATE         object
#  5   CANPROV          object
#  6   COUNTRY          int64
#  7   VALUE            int64
#  8   SHIPWT           int64
#  9   FREIGHT_CHARGES  int64
#  10  DF               float64
#  11  CONTCODE         object
#  12  MONTH            float64
#  13  YEAR             int64
#  14  COMMODITY2       float64
# dtypes: float64(3), int64(7), object(5)
# memory usage: 2.7+ GB

# %%
df_2020_2024.isna().sum()
# Out:
# TRDTYPE                   0
# USASTATE            3454110
# DEPE               15141823
# DISAGMOT                  0
# MEXSTATE           17356547
# CANPROV            11555270
# COUNTRY                   0
# VALUE                     0
# SHIPWT                    0
# FREIGHT_CHARGES           0
# DF                  8106109
# CONTCODE                  0
# MONTH                244796
# YEAR                      0
# COMMODITY2          5519344
# dtype: int64

# %%
#replace values of some of the columns

df_2020_2024['DISAGMOT'] = df_2020_2024['DISAGMOT'].replace({
    1:'Vessel',
    3:'Air',
    4:'Mail (U.S. Postal Service)',
    5:'Truck',
    6:'Rail',
    7:'Pipeline',
    8:'Other',
    9:'Foreign Trade Zones (FTZs)'
}
)

# %%
df_2020_2024['CONTCODE'] = df_2020_2024['CONTCODE'].replace({
    'X':'Containerized',
    '0':'Non-Containerized'
})

# %%
df_2020_2024['TRDTYPE'] = df_2020_2024['TRDTYPE'].replace({
    1:'Export',
    2:'Import'
})

# %%
df_2020_2024['COUNTRY'] = df_2020_2024['COUNTRY'].replace({
    1220:'Canada',
    2010:'Mexico'
})

# %%
df_2020_2024['DF'] = df_2020_2024['DF'].replace({
    1.0:'domestically produced merchandise',
    2.0:'foreign produced merchandise'
})

# %%
df_2020_2024['MONTH'] = df_2020_2024['MONTH'].replace({
    1.0:'January',
    2.0:'February',
    3.0:'March',
    4.0:'April',
    5.0:'May',
    6.0:'June',
    7.0:'July',
    8.0:'August',
    9.0:'September',
    10.0:'October',
    11.0:'November',
    12.0:'December'
})

# %%
df_2020_2024['MEXSTATE'] = df_2020_2024['MEXSTATE'].replace({
    "AG": "Aguascalientes",
    "BC": "Baja California",
    "BN": "Baja California Norte",
    "BS": "Baja California Sur",
    "CH": "Chihuahua",
    "CL": "Colima",
    "CM": "Campeche",
    "CO": "Coahuila",
    "CS": "Chiapas",
    "DF": "Distrito Federal",
    "DG": "Durango",
    "GR": "Guerrero",
    "GT": "Guanajuato",
    "HG": "Hidalgo",
    "JA": "Jalisco",
    "MI": "Michoacán",
    "MO": "Morelos",
    "MX": "Estado de Mexico",
    "NA": "Nayarit",
    "NL": "Nuevo Leon",
    "OA": "Oaxaca",
    "PU": "Puebla",
    "QR": "Quintana Roo",
    "QT": "Queretaro",
    "SI": "Sinaloa",
    "SL": "San Luis Potosi",
    "SO": "Sonora",
    "TB": "Tabasco",
    "TL": "Tlaxcala",
    "TM": "Tamaulipas",
    "VE": "Veracruz",
    "YU": "Yucatan",
    "ZA": "Zacatecas",
    "OT": "State Unknown"
})

# %%
df_2020_2024['USASTATE'] = df_2020_2024['USASTATE'].replace({
     "AL": "Alabama",
    "AK": "Alaska",
    "AS": "American Samoa",
    "AZ": "Arizona",
    "AR": "Arkansas",
    "CA": "California",
    "CO": "Colorado",
    "CT": "Connecticut",
    "DE": "Delaware",
    "DC": "District of Columbia",
    "FL": "Florida",
    "GA": "Georgia",
    "HI": "Hawaii",
    "ID": "Idaho",
    "IL": "Illinois",
    "IN": "Indiana",
    "IA": "Iowa",
    "KS": "Kansas",
    "KY": "Kentucky",
    "LA": "Louisiana",
    "ME": "Maine",
    "MD": "Maryland",
    "MA": "Massachusetts",
    "MI": "Michigan",
    "MN": "Minnesota",
    "MS": "Mississippi",
    "MO": "Missouri",
    "MT": "Montana",
    "NE": "Nebraska",
    "NV": "Nevada",
    "NH": "New Hampshire",
    "NJ": "New Jersey",
    "NM": "New Mexico",
    "NY": "New York",
    "NC": "North Carolina",
    "ND": "North Dakota",
    "OH": "Ohio",
    "OK": "Oklahoma",
    "OR": "Oregon",
    "PA": "Pennsylvania",
    "RI": "Rhode Island",
    "SC": "South Carolina",
    "SD": "South Dakota",
    "TN": "Tennessee",
    "TX": "Texas",
    "UT": "Utah",
    "VT": "Vermont",
    "VA": "Virginia",
    "WA": "Washington",
    "WV": "West Virginia",
    "WI": "Wisconsin",
    "WY": "Wyoming",
    "DU": "Unknown"
})

# %%
df_2020_2024.describe()
# Out:
#               VALUE        SHIPWT  FREIGHT_CHARGES          YEAR    COMMODITY2
# count  2.411528e+07  2.411528e+07     2.411528e+07  2.411528e+07  1.859593e+07
# mean   2.864612e+06  1.262405e+06     3.845418e+04  2.021376e+03  5.665994e+01
# std    4.307514e+07  5.087200e+07     1.215599e+06  1.227826e+00  2.785076e+01
# min    0.000000e+00  0.000000e+00     0.000000e+00  2.020000e+03  1.000000e+00
# 25%    1.402100e+04  0.000000e+00     0.000000e+00  2.020000e+03  3.300000e+01
# 50%    6.948900e+04  0.000000e+00     2.450000e+02  2.021000e+03  6.000000e+01
# 75%    4.166380e+05  2.523000e+03     2.760000e+03  2.023000e+03  8.400000e+01
# max    3.428679e+10  8.279288e+10     1.901790e+09  2.024000e+03  9.900000e+01

# %% [markdown]
# RENAMING COLUMN HEADERS TO MAKE IT MORE DESCRIPTIVE

# %%
#rename headers

df_2020_2024.rename(
    columns={
        'CANPROV': 'Canadian Province', 
        'SHIPWT': 'Shipping Weight (kg)',
        'TRDTYPE': 'Trade Type',
        'USASTATE': 'US State Code',
        'VALUE': 'Value (USD)',
        'YEAR': 'Year',
        'DEPE': 'Port/District Code',
        'MONTH': 'Month',
        'DISAGMOT': 'Mode of Transportation',
        'MEXSTATE': 'Mexican State Code',
        'FREIGHT_CHARGES': 'Freight Charges (USD)',
        'DF': 'Domestic/Foreign Code',
        'COUNTRY': 'Country',
        'CONTCODE': 'Container',
        'COMMODITY2': 'Commodity Classification Code'
    
    }, inplace=True
)

# %%
df_2020_2024.head()
# Out:
#   Trade Type US State Code Port/District Code Mode of Transportation  \
# 0     Export        Alaska               0115                  Truck
# 1     Export        Alaska               0901                  Truck
# 2     Export        Alaska               20XX                 Vessel
# 3     Export        Alaska               20XX                    Air
# 4     Export        Alaska               20XX                    Air
#
#   Mexican State Code Canadian Province Country  Value (USD)  \
# 0                NaN                XB  Canada         4660
# 1                NaN                XO  Canada        14360
# 2                 XX               NaN  Mexico      4293733
# 3                NaN                XA  Canada        28283
# 4                NaN                XA  Canada        29848
#
#    Shipping Weight (kg)  Freight Charges (USD)  \
# 0                     0                     67
# 1                     0                    282
# 2              24971000                      0
# 3                   443                    563
# 4                    69                    538
#
#                Domestic/Foreign Code          Container  Month  Year  \
# 0       foreign produced merchandise      Containerized  April  2020
# 1  domestically produced merchandise      Containerized  April  2020
# 2  domestically produced merchandise  Non-Containerized  April  2020
# 3  domestically produced merchandise      Containerized  April  2020
# 4       foreign produced merchandise      Containerized  April  2020
#
#    Commodity Classification Code
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %% [markdown]
# In this section, I answer the following business questions to further explore the dataset. The questions are;

# %% [markdown]
# *Freight Movement Patterns*
#
# What are the most common modes of transportation used for exports and import across the US, and how do they compare in terms of shipping weight and value?
#  → Helps you understand transportation mode preferences and efficiency.
#
#
# Between Canada and Mexico, which country receive the highest volume and value of exports from the US?
#  → Useful for identifying strong trade relationships and potential market expansion.
#
#
# Is there any correlation between the type of container (Containerized vs Non-Containerized) and shipping costs or weight?
#  → Can guide container usage optimization.
#
#
# _Operational Inefficiencies_
#
# Which ports/districts handle the most freight, and do they also incur the highest freight charges?
#  → This can reveal bottlenecks or inefficiencies at specific ports.
#
#
# Are there transportation modes or routes that consistently report zero or very low shipping weight but incur high freight charges?
#  → Highlights potential underutilization or inefficiencies in resource usage.
#
#
# _Environmental Impact_
#
# Which transportation modes have the highest freight charges per kilogram of weight shipped?
#  → Could be a proxy for energy intensity or environmental cost.
#
#
# How does the distribution of shipping weights across different transportation modes inform us about their likely environmental impact?
#  → Lighter shipments via air, for instance, might have higher emissions per kg than heavier sea freight.

# %%
# Step 1: Group by Trade Type and Mode of Transportation
summary = df_2020_2024.groupby(['Trade Type', 'Mode of Transportation']).agg({
    'Shipping Weight (kg)': 'sum',
    'Value (USD)': 'sum',
    'Mode of Transportation': 'count'  # Frequency count
}).rename(columns={'Mode of Transportation': 'Count'}).reset_index()

# Step 2: Sort for better readability (optional)
summary = summary.sort_values(by='Count', ascending=False)

# Display the summary table
summary
# Out:
#    Trade Type      Mode of Transportation  Shipping Weight (kg)  \
# 5      Export                       Truck                     0
# 13     Import                       Truck         6108372683750
# 0      Export                         Air           11335520321
# 7      Import                         Air            5815888537
# 4      Export                        Rail                     0
# 12     Import                        Rail         4921740135897
# 2      Export                       Other                     0
# 14     Import                      Vessel         5714120617829
# 6      Export                      Vessel         4297756014672
# 8      Import  Foreign Trade Zones (FTZs)          223810391352
# 10     Import                       Other           13325474006
# 1      Export  Mail (U.S. Postal Service)                     0
# 11     Import                    Pipeline         9146974766582
# 3      Export                    Pipeline                     0
# 9      Import  Mail (U.S. Postal Service)                  3753
#
#        Value (USD)     Count
# 5   20009069381100  10986447
# 13  23917855824935   4822537
# 0    1585367003605   2621120
# 7    1118841528381   1507581
# 4    3393704888326   1331788
# 12   6137745335296   1160161
# 2    2193791362678    725639
# 14   2906239256396    425056
# 6    2119520767547    294127
# 8     368251247528     92789
# 10    628426282541     70769
# 1       1414714051     28585
# 11   3711721754613     26867
# 3     988959179640     21462
# 9          6026205       349

# %%
plt.figure(figsize=(12, 10))
sns.barplot(data=summary, x='Mode of Transportation', y='Value (USD)', hue='Trade Type')
plt.title('Value (USD) by Mode of Transportation (Export vs Import)')
plt.ylabel('Value (USD)')
plt.xlabel('Mode of Transportation')
plt.xticks(rotation=45)
plt.legend(title='Trade Type')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.barplot(data=summary, x='Mode of Transportation', y='Shipping Weight (kg)', hue='Trade Type')
plt.title('Shipping Weight (kg) by Mode of Transportation (Export vs Import)')
plt.ylabel('Shipping Weight (kg)')
plt.xlabel('Mode of Transportation')
plt.xticks(rotation=45)
plt.legend(title='Trade Type')
plt.tight_layout()
plt.show()

# %%
# Between canada and Mexico, which one has the highest number of export

# %%
# Step 1: Filter for Export records to Canada and Mexico
us_exports = df_2020_2024[
    (df_2020_2024['Trade Type'] == 'Export') &
    (df_2020_2024['Country'].isin(['Canada', 'Mexico']))
]

export_count_value = us_exports.groupby('Country').agg({
    'Country': 'count' ,
    'Value (USD)': 'sum'
}).rename(columns={'count': 'Export Count'})

export_count_value.columns = [
    'Export Count',
    'Total Value (USD)'
]

# Step 4: Reset index for display
export_count_value_table = export_count_value.reset_index()

# Display the result
export_count_value_table
# Out:
#   Country  Export Count  Total Value (USD)
# 0  Canada       8402233     15975410512576
# 1  Mexico       7606935     14316416784371

# %% [markdown]
# FEATURE ENGINEERING

# %%
#encode container type

# %%
df_2020_2024['Container Encoded'] = df_2020_2024['Container'].map({'Containerized': 1, 'Non-Containerized': 0})
correlation = df_2020_2024[['Container Encoded', 'Shipping Weight (kg)', 'Value (USD)']].corr()

correlation
# Out:
#                       Container Encoded  Shipping Weight (kg)  Value (USD)
# Container Encoded              1.000000             -0.016796    -0.019593
# Shipping Weight (kg)          -0.016796              1.000000     0.521739
# Value (USD)                   -0.019593              0.521739     1.000000

# %% [markdown]
# ENVIRONMENTAL IMPACT

# %%
#highest freight charges per kilogram of weight shipped per mode of transportation

# %%
data_with_no_zero_shipping_weight = df_2020_2024[df_2020_2024['Shipping Weight (kg)'] > 0]
data_with_no_zero_shipping_weight['Value per kg'] = data_with_no_zero_shipping_weight['Value (USD)'] / data_with_no_zero_shipping_weight['Shipping Weight (kg)']
value_per_kg_by_mode = data_with_no_zero_shipping_weight.groupby('Mode of Transportation').agg({
    'Value per kg': 'mean',
    'Shipping Weight (kg)': 'sum',
    'Value (USD)': 'sum'
}).reset_index()
value_per_kg_by_mode = value_per_kg_by_mode.sort_values(by='Value per kg', ascending=False)

value_per_kg_by_mode
# Out:
# <ipython-input-34-53c0d727817a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_with_no_zero_shipping_weight['Value per kg'] = data_with_no_zero_shipping_weight['Value (USD)'] / data_with_no_zero_shipping_weight['Shipping Weight (kg)']
#        Mode of Transportation  Value per kg  Shipping Weight (kg)  \
# 3                       Other  44432.972557           13325474006
# 2  Mail (U.S. Postal Service)   7390.286739                  3753
# 0                         Air   1021.658480           17151408858
# 1  Foreign Trade Zones (FTZs)    143.060807          223810391352
# 7                      Vessel     98.533336        10011876632501
# 6                       Truck     83.398278         6108372683750
# 5                        Rail      3.464180         4921740135897
# 4                    Pipeline      2.612828         9146974766582
#
#       Value (USD)
# 3    212179101857
# 2         6026205
# 0   2703572261725
# 1    368250639710
# 7   5024830877056
# 6  23917738719561
# 5   6137527350232
# 4   3397766631841

# %%
plt.figure(figsize=(12, 10))
bars = plt.bar(value_per_kg_by_mode['Mode of Transportation'], value_per_kg_by_mode['Value per kg'], color='blue')

# Add labels
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.2f}', ha='center', fontsize=9)

plt.title('Average Freight Charge per Kilogram by Transportation Mode')
plt.ylabel('Value per kg (USD)')
plt.xlabel('Mode of Transportation')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
